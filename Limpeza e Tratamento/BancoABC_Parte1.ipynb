# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
dados = pd.read_csv('/content/Bank Customer Churn Prediction.csv')
dados
# Out:
#       customer_id  credit_score  country  gender  age  tenure    balance  \
# 0        15634602           619   France  Female   42       2       0.00
# 1        15647311           608    Spain  Female   41       1   83807.86
# 2        15619304           502   France  Female   42       8  159660.80
# 3        15701354           699   France  Female   39       1       0.00
# 4        15737888           850    Spain  Female   43       2  125510.82
# ...           ...           ...      ...     ...  ...     ...        ...
# 9995     15606229           771   France    Male   39       5       0.00
# 9996     15569892           516   France    Male   35      10   57369.61
# 9997     15584532           709   France  Female   36       7       0.00
# 9998     15682355           772  Germany    Male   42       3   75075.31
# 9999     15628319           792   France  Female   28       4  130142.79
#
#       products_number  credit_card  active_member  estimated_salary  churn
# ...

# %%
#Tudo ok sem valores faltantes
dados.isnull().sum()
# Out:
# customer_id         0
# credit_score        0
# country             0
# gender              0
# age                 0
# tenure              0
# balance             0
# products_number     0
# credit_card         0
# active_member       0
# estimated_salary    0
# churn               0
# dtype: int64

# %%
#Não há registros duplicados
dados.duplicated('customer_id').sum()
# Out:
# 0

# %%
dados.drop(['customer_id'], axis = 1, inplace = True)

# %%
#Tenure = fidelidade em anos (tempo que possui a conta nesse banco)
#balance = saldo em conta
#products_number = numero de produtos do banco
#credit_car= quantidade de cartoes de creditos
#é um membro ativo do banco?
#churn = 1 cliente saiu / 0 cliente ficou
dados
# Out:
#       credit_score  country  gender  age  tenure    balance  products_number  \
# 0              619   France  Female   42       2       0.00                1
# 1              608    Spain  Female   41       1   83807.86                1
# 2              502   France  Female   42       8  159660.80                3
# 3              699   France  Female   39       1       0.00                2
# 4              850    Spain  Female   43       2  125510.82                1
# ...            ...      ...     ...  ...     ...        ...              ...
# 9995           771   France    Male   39       5       0.00                2
# 9996           516   France    Male   35      10   57369.61                1
# 9997           709   France  Female   36       7       0.00                1
# 9998           772  Germany    Male   42       3   75075.31                2
# 9999           792   France  Female   28       4  130142.79                1
#
# ...

# %%
dados.columns = ['Score', 'País', 'Gênero', 
                 'Idade', 'Fidelidade', 'Saldo', 
                 'Produtos', 'Cartão', 'Ativo?', 
                 'Salário', 'Churn']
dados
# Out:
#       Score     País  Gênero  Idade  Fidelidade      Saldo  Produtos  Cartão  \
# 0       619   France  Female     42           2       0.00         1       1
# 1       608    Spain  Female     41           1   83807.86         1       0
# 2       502   France  Female     42           8  159660.80         3       1
# 3       699   France  Female     39           1       0.00         2       0
# 4       850    Spain  Female     43           2  125510.82         1       1
# ...     ...      ...     ...    ...         ...        ...       ...     ...
# 9995    771   France    Male     39           5       0.00         2       1
# 9996    516   France    Male     35          10   57369.61         1       1
# 9997    709   France  Female     36           7       0.00         1       0
# 9998    772  Germany    Male     42           3   75075.31         2       1
# 9999    792   France  Female     28           4  130142.79         1       1
#
#       Ativo?    Salário  Churn
# ...
